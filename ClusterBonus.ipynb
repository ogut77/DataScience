# %% [markdown]
# <a href="https://colab.research.google.com/github/ogut77/DataScience/blob/main/ClusterBonus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import numpy as np
bn=pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bonus.csv')
bn
# Out:
#     Economy  Speed  Color  Price
# 0     63.38  35.47  27.11  74.88
# 1     63.32  33.43  34.71  63.31
# 2     43.06  22.04  35.99  56.62
# 3     60.13  34.40  37.12  53.70
# 4     75.73  22.90  28.03  64.21
# 5     49.79  44.06  36.22  62.03
# 6     56.46  43.61  30.65  65.49
# 7     51.04  21.89  24.68  57.60
# 8     55.09  40.33  37.08  71.70
# 9     52.90  15.89  33.48  59.17
# 10    63.90  31.38  27.66  65.70
# 11    62.37  14.22  26.00  58.50
# 12    60.22  37.15  30.59  60.70
# 13    46.04  38.63  40.34  64.15
# 14    72.55   8.08  38.98  71.76
# 15    71.56  38.76  28.34  66.61
# 16    97.18  60.12  53.56  76.21
# 17    99.58  56.40  72.12  76.94
# 18   100.50  58.27  70.14  78.87
# 19    98.95  52.55  63.08  80.46
# 20    95.79  49.77  69.94  76.79
# 21    99.04  60.79  61.94  71.47
# 22   117.40  66.14  74.09  78.38
# 23    95.64  56.88  64.29  76.59
# 24   109.27  54.04  58.45  77.34
# 25   103.39  40.78  70.58  78.83
# 26   117.48  59.56  65.73  83.66
# 27   108.75  56.38  57.13  75.28
# 28   106.02  55.41  72.94  77.24
# 29   112.65  66.01  50.41  73.21
# 30   106.16  51.80  64.08  73.03
# 31   112.04  51.97  63.42  82.84
# 32   109.91  66.20  64.63  78.81
# 33     7.16  29.95  83.45  13.82
# 34     2.15  23.08  95.79  21.51
# 35    16.71  34.43  75.45  13.96
# 36    14.65  27.46  90.05  10.17
# 37     6.75  33.29  81.37   4.41
# 38    27.29  23.36  94.14   8.06
# 39     5.91  17.72  80.67   2.81
# 40    23.72  26.10  83.28  13.04
# 41    28.82  28.74  87.12  20.08
# 42     1.99  25.98  79.42  13.42
# 43     1.93  22.72  86.82  20.18
# 44    19.53  35.12  90.31   2.47
# 45    21.13  32.05  89.84  12.44
# 46    32.26  23.98  82.14   7.61
# 47    31.67  35.83  85.42  15.89
# 48    19.35  30.36  78.95   5.32
# 49    21.40  20.72  80.09  19.67

# %%
bn.corr()
# Out:
#           Economy     Speed     Color     Price
# Economy  1.000000  0.771567 -0.354676  0.910017
# Speed    0.771567  1.000000  0.022898  0.620146
# Color   -0.354676  0.022898  1.000000 -0.618228
# Price    0.910017  0.620146 -0.618228  1.000000

# %%
# huge jump in distance is typically what we're interested in
# if we want to argue for a certain number of clusters. 
import scipy.cluster.hierarchy as shc

plt.figure(figsize=(10, 7))
plt.title("Customer Dendograms")
dend = shc.dendrogram(shc.linkage(bn, method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
cl=cluster.fit_predict(bn)

# %%
#Calculate Centroids
cl2=pd.DataFrame(cl)
bon2=pd.concat([bn,cl2],axis=1)
bon2.groupby(0).mean().T
# Out:
# 0                0          1           2
# Economy  59.221250  16.612941  105.279412
# Speed    30.140000  27.699412   56.651176
# Color    32.311250  84.959412   64.501765
# Price    63.508125  12.050588   77.408824
